# %%
import pandas as pd

# %%
data = pd.read_csv("../Data/Dallas_UOF_2015_CSV.csv")

# %%
data.head()
# Out:
#     ID      FILENUM Occurred Date Occurred Time  Badge Number  OffSex OffRace  \
# 0  499  UF2015-0011    01/01/2015          1:09         9672.0   Male   White
# 1  500  UF2015-0011    01/01/2015          1:24        10624.0   Male   White
# 2  515  UF2015-0016    01/01/2015         22:34         9581.0   Male   Black
# 3  488  UF2015-0001    01/01/2015          3:28         9252.0   Male   White
# 4  501  UF2015-0011    01/01/2015          1:24        10688.0   Male   White
#
#     Hire Date OFF_INJURED                   OffCondType  \
# 0  12/10/2008          No  No injuries noted or visible
# 1  08/14/2013          No  No injuries noted or visible
# 2  08/20/2008          No  No injuries noted or visible
# 3  09/26/2007          No  No injuries noted or visible
# 4  11/06/2013          No  No injuries noted or visible
#
#                          ...                         CIT_ARRESTED  \
# 0                        ...                                  Yes
# ...

# %%
data.GeoLocation[]
